# %% [markdown]
# # Sharing Tentang Robot Terbang
#
# oleh:
# <br>
# **Ardy Seto Priambodo, S.T., M.Eng.**
# <br>
# materi bisa diakses di: https://s.id/kHYxI

# %% [markdown]
# ## Teori
#
# A quadcopter, also called a quadrotor helicopter or quadrotor,[1] is a multirotor helicopter[2] that is lifted and propelled by four rotors. Quadcopters are classified as rotorcraft, as opposed to fixed-wing aircraft, because their lift is generated by a set of rotors (vertically oriented propellers).
# <br>
# sumber: https://en.wikipedia.org/wiki/Quadcopter
#
# <img src="pic/quadcopter.png" width="450"/>
# <center>sumber: https://google.com</center>

# %% [markdown]
# ## Cara Terbang
#
# <img src="pic/cara-terbang.jpg" width="350"/>
# <center>sumber: https://google.com</center>
# <br>
# <br>
#
# ### Up / Down
# <img src="pic/moving-up-down.png" width="400"/>
# <center>sumber: http://uav-society.blogspot.com/2014/06/quadcopter-mechanics.html</center>
#
# ### Pitch
# <img src="pic/moving-pitch.png" width="400"/>
# <center>sumber: http://uav-society.blogspot.com/2014/06/quadcopter-mechanics.html</center>
#
# ### Roll
# <img src="pic/moving-roll.png" width="400"/>
# <center>sumber: http://uav-society.blogspot.com/2014/06/quadcopter-mechanics.html</center>
#
# ### Yaw
# <img src="pic/moving-yaw.png" width="400"/>
# <center>sumber: http://uav-society.blogspot.com/2014/06/quadcopter-mechanics.html</center>

# %% [markdown]
# ## Komponen
# <img src="pic/pixhawk-full.jpg" width="850"/>
# <center>Pixhawk Wiring Full</center>
# <center>sumber: http://ardupilot.com</center>
#
# ### Frame
# <img src="pic/frame-quadcopter.jpg" width="400"/>
# <center>Frame S550</center>
# <center>sumber: http://amazon.com</center>
#
# <img src="pic/frame-hexacopter.jpg" width="500"/>
# <center>Frame S680</center>
# <center>sumber: http://amazon.com</center>
#
# ### Motor
# <img src="pic/motor-brushless.png" width="400"/>
# <center>Motor Brushless 2508</center>
# <center>sumber: https://www.racerstar.com/</center>
#
# <img src="pic/motor-part.jpg" width="500"/>
# <center>Motor Components</center>
# <center>sumber: https://oscarliang.com/</center>
#
# <img src="pic/motor-code.jpg" width="400"/>
# <center>Motor Code</center>
# <center>sumber: https://www.unmannedtech.co.uk/</center>
#
# ### ESC
# <img src="pic/esc.png" width="400"/>
# <center>ESC 30A</center>
# <center>sumber: https://www.hobbywing.com/</center>
#
# ### Baterai
# <img src="pic/lipo-battery.jpg" width="400"/>
# <center>Lipo Battery 5000mAh 4S</center>
# <center>sumber: http://hobbyking.com</center>
#
# ### Flight Controller + GPS (Opsional) + Telemetry (Opsional)
# <img src="pic/pixhawk.jpg" width="450"/>
# <center>Pixhawk</center>
# <center>sumber: http://google.com</center>
#
# <img src="pic/betaflight-f3.png" width="350"/>
# <center>Betaflight F3</center>
# <center>sumber: http://google.com</center>
#
# <img src="pic/betaflight-f4.png" width="350"/>
# <center>Betaflight F4</center>
# <center>sumber: http://google.com</center>
#
# ### Radio Control
# <img src="pic/taranis-xlite.png" width="400"/>
# <center>Taranis X-Lite</center>
# <center>sumber: https://www.frsky-rc.com/</center>
#
# <img src="pic/taranis-x9d.png" width="400"/>
# <center>Taranis X9D</center>
# <center>sumber: https://www.frsky-rc.com/</center>
#
# <img src="pic/flysky-i6.jpg" width="400"/>
# <center>Flysky i6</center>
# <center>sumber: https://www.flysky-cn.com/</center>
#
# ### FPV Set (Opsional)
# <img src="pic/fpv-cam-vtx.jpg" width="400"/>
# <center>FPV Camera dan Video Transmitter</center>
# <center>sumber: http://banggood.com</center>
#
# <img src="pic/fatshark.png" width="400"/>
# <center>FPV Googles</center>
# <center>sumber: http://amazon.com</center>
#
# <img src="pic/fpv-monitor.jpg" width="400"/>
# <center>FPV Monitor</center>
# <center>sumber: https://www.getfpv.com</center>
#
# ### Gimbal (Opsional)
# <img src="pic/gimbal-gopro.jpg" width="400"/>
# <center>Gimbal GoPro</center>
# <center>sumber: http://google.com</center>
#
# ### Ground Station (Opsional)
# <img src="pic/ground-station.jpg" width="500"/>
# <center>Ground Station</center>
# <center>sumber: http://amazon.com</center>

# %% [markdown]
# ## Peluang Riset
#
# ### Frame
# <img src="pic/folded-quad-1.png" width="600"/>
# <img src="pic/folded-quad-2.png" width="600"/>
# <img src="pic/folded-quad-3.png" width="600"/>
# <center>Folded Quadcopter</center>
# <center>sumber: https://www.youtube.com/watch?v=jmKXCdEbF_E</center>
#
# ### Elektronika
# <img src="pic/diy-esc.png" width="600"/>
# <center>DIY ESC</center>
# <center>sumber: https://www.youtube.com/watch?v=G9PHqN9vmVI</center>
#
# ### Metode Terbang
# <img src="pic/moving-landing-1.jpg" width="600"/>
# <img src="pic/moving-landing-2.jpg" width="600"/>
# <img src="pic/moving-landing-3.jpg" width="600"/>
# <center>Moving Landing Quadcopter</center>
# <center>sumber: https://www.youtube.com/watch?v=Tz5ubwoAfNE</center>
#
#
# ### Simulasi
# <img src="pic/quad-simulation.png" width="600"/>
# <center>Simulation Quadcopter</center>
# <center>sumber: https://github.com/2black0/matlab_quadcopter</center>
#
# ### Kendali dan Telemetri
# <img src="pic/antenna-tracker.png" width="600"/>
# <center>Antenna Tracker</center>
# <center>sumber: https://www.youtube.com/watch?v=fTGyGfEibGc</center>
